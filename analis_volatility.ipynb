# %%
import matplotlib.pyplot as plt
import pandas as pd
import math
import numpy as np

# %%
data = pd.read_csv("volatility.txt", sep=" ")
data
# Out:
#       0.0  0.0.1
# 0    1.50   3.54
# 1    1.51   3.54
# 2    1.62   3.60
# 3    1.64   3.64
# 4    1.72   3.70
# ..    ...    ...
# 356  2.91  11.13
# 357  2.87  11.06
# 358  2.64  10.86
# 359  2.56  10.82
# 360  2.24  10.82
#
# [361 rows x 2 columns]

# %%
plt.scatter(np.arange(len(data["0.0"])), data["0.0"], c="blue", s=1)
plt.scatter(np.arange(len(data["0.0.1"])),data["0.0.1"], c="red",s=1)
plt.show()
#t_max = 30

# %%
q90 = np.percentile(data["0.0.1"],90)
q90
q10 = np.percentile(data["0.0"],10)
q90
np.mean(data["0.0.1"])
np.percentile(data["0.0.1"],50)
# Out:
# np.float64(6.59)

# %%
data = pd.read_csv("volatility.txt", sep=" ")
data
plt.scatter(np.arange(len(data["0.0"])), data["0.0"], c="blue", s=1)
plt.scatter(np.arange(len(data["0.0.1"])),data["0.0.1"], c="red",s=1)
plt.show() #t_max = 10

# %%
print(np.percentile(data["0.0"],25),np.percentile(data["0.0.1"],25))
print(np.mean(data["0.0"]),np.mean(data["0.0.1"]))
# Out:
# 3.5725 7.86
# 5.925289256198347 9.620206611570248

# %%
data = pd.read_csv("volatility.txt", sep=" ")
data
plt.scatter(np.arange(len(data["0.0"])), data["0.0"], c="blue", s=1)
plt.scatter(np.arange(len(data["0.0.1"])),data["0.0.1"], c="red",s=1)
plt.show() #t_max = 5

# %%
print("q75    " + str(np.percentile(data["0.0"],75)) + "     " + str(np.percentile(data["0.0.1"],75)))
print("mid    " + str(round(np.mean(data["0.0"]),2)) + "     " + str(round(np.mean(data["0.0.1"]),2)))
print("q25    " + str(np.percentile(data["0.0"],25)) + "     " + str(np.percentile(data["0.0.1"],25)))
# Out:
# 5.26 8.535
# 4.164168466522678 6.790259179265658
# 2.375 4.905

# %%
data = pd.read_csv("volatility.txt", sep=" ")
data
plt.scatter(np.arange(len(data["0.0"])), data["0.0"], c="blue", s=1)
plt.scatter(np.arange(len(data["0.0.1"])),data["0.0.1"], c="red",s=1)
plt.show() #t_max = 50

# %%
print("q75    " + str(np.percentile(data["0.0"],75)) + "     " + str(np.percentile(data["0.0.1"],75)))
print("mid    " + str(round(np.mean(data["0.0"]),2)) + "     " + str(round(np.mean(data["0.0.1"]),2)))
print("q25    " + str(np.percentile(data["0.0"],25)) + "     " + str(np.percentile(data["0.0.1"],25)))
# Out:
# q75    1.44     6.845
# mid    1.15     5.28
# q25    0.72     3.07

# %%
data = pd.read_csv("volatility.txt", sep=" ")
data
plt.scatter(np.arange(len(data["0.0"])), data["0.0"], c="blue", s=1)
plt.scatter(np.arange(len(data["0.0.1"])),data["0.0.1"], c="red",s=1)
plt.show() #t_max = 100

# %%
print("q75    " + str(np.percentile(data["0.0"],75)) + "     " + str(np.percentile(data["0.0.1"],75)))
print("mid    " + str(round(np.mean(data["0.0"]),2)) + "     " + str(round(np.mean(data["0.0.1"]),2)))
print("q25    " + str(np.percentile(data["0.0"],25)) + "     " + str(np.percentile(data["0.0.1"],25)))
# Out:
# q75    0.54     3.4
# mid    0.44     2.99
# q25    0.31     2.4425

# %%
data = pd.read_csv("volatility.txt", sep=" ")
data
plt.scatter(np.arange(len(data["0.0"])), data["0.0"], c="blue", s=1)
plt.scatter(np.arange(len(data["0.0.1"])),data["0.0.1"], c="red",s=1)
plt.show() #t_max = 20

# %%
print("q75    " + str(np.percentile(data["0.0"],75)) + "     " + str(np.percentile(data["0.0.1"],75)))
print("mid    " + str(round(np.mean(data["0.0"]),2)) + "     " + str(round(np.mean(data["0.0.1"]),2)))
print("q25    " + str(np.percentile(data["0.0"],25)) + "     " + str(np.percentile(data["0.0.1"],25)))
# Out:
# q75    1.9625     8.865
# mid    1.68     6.52
# q25    0.92     4.355

# %%
data = pd.read_csv("volatility.txt", sep=" ")
data
plt.scatter(np.arange(len(data["0.0"])), data["0.0"], c="blue", s=1)
plt.scatter(np.arange(len(data["0.0.1"])),data["0.0.1"], c="red",s=1)
plt.show() #t_max = 40

# %%
print("q75    " + str(np.percentile(data["0.0"],75)) + "     " + str(np.percentile(data["0.0.1"],75)))
print("mid    " + str(round(np.mean(data["0.0"]),2)) + "     " + str(round(np.mean(data["0.0.1"]),2)))
print("q25    " + str(np.percentile(data["0.0"],25)) + "     " + str(np.percentile(data["0.0.1"],25)))
# Out:
# q75    1.5825     5.842499999999999
# mid    1.33     4.96
# q25    0.68     3.91

# %%
data = pd.read_csv("volatility.txt", sep=" ")
data
plt.scatter(np.arange(len(data["0.0"])), data["0.0"], c="blue", s=1)
plt.scatter(np.arange(len(data["0.0.1"])),data["0.0.1"], c="red",s=1)
plt.show() #t_max = 80

# %%
print("q75    " + str(np.percentile(data["0.0"],75)) + "     " + str(np.percentile(data["0.0.1"],75)))
print("mid    " + str(round(np.mean(data["0.0"]),2)) + "     " + str(round(np.mean(data["0.0.1"]),2)))
print("q25    " + str(np.percentile(data["0.0"],25)) + "     " + str(np.percentile(data["0.0.1"],25)))
# Out:
# q75    0.78     5.4125
# mid    0.66     4.24
# q25    0.4     3.0975

# %%
data = pd.read_csv("volatility.txt", sep=" ")
data
plt.scatter(np.arange(len(data["0.0"])), data["0.0"], c="blue", s=1)
plt.scatter(np.arange(len(data["0.0.1"])),data["0.0.1"], c="red",s=1)
plt.show() #t_max = 150

# %%
print("q75    " + str(np.percentile(data["0.0"],75)) + "     " + str(np.percentile(data["0.0.1"],75)))
print("mid    " + str(round(np.mean(data["0.0"]),2)) + "     " + str(round(np.mean(data["0.0.1"]),2)))
print("q25    " + str(np.percentile(data["0.0"],25)) + "     " + str(np.percentile(data["0.0.1"],25)))
# Out:
# q75    0.39     3.6
# mid    0.3     3.27
# q25    0.19     2.81

# %%
data = pd.read_csv("volatility.txt", sep=" ")
data
plt.scatter(np.arange(len(data["0.0"])), data["0.0"], c="blue", s=1)
plt.scatter(np.arange(len(data["0.0.1"])),data["0.0.1"], c="red",s=1)
plt.show() #t_max = 60

# %%
print("q75    " + str(np.percentile(data["0.0"],75)) + "     " + str(np.percentile(data["0.0.1"],75)))
print("mid    " + str(round(np.mean(data["0.0"]),2)) + "     " + str(round(np.mean(data["0.0.1"]),2)))
print("q25    " + str(np.percentile(data["0.0"],25)) + "     " + str(np.percentile(data["0.0.1"],25)))
# Out:
# q75    1.03     3.255
# mid    0.82     3.22
# q25    0.54     2.48

# %%
data = pd.read_csv("volatility.txt", sep=" ")
data
plt.scatter(np.arange(len(data["0.0"])), data["0.0"], c="blue", s=1)
plt.scatter(np.arange(len(data["0.0.1"])),data["0.0.1"], c="red",s=1)
plt.show() #t_max = 70

# %%
print("q75    " + str(np.percentile(data["0.0"],75)) + "     " + str(np.percentile(data["0.0.1"],75)))
print("mid    " + str(round(np.mean(data["0.0"]),2)) + "     " + str(round(np.mean(data["0.0.1"]),2)))
print("q25    " + str(np.percentile(data["0.0"],25)) + "     " + str(np.percentile(data["0.0.1"],25)))
# Out:
# q75    1.09     4.3
# mid    0.89     3.91
# q25    0.61     3.12
